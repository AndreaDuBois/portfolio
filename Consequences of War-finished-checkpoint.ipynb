# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime
import matplotlib.ticker as ticker
warnings.filterwarnings("ignore")
import matplotlib as mpl
# %matplotlib inline
import panel as pn
import pandas_bokeh
import missingno as msno
import warnings
pandas_bokeh.output_notebook()
import cufflinks as cf
from IPython.display import display,HTML
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('Downloads/Poverty.csv') #import files
data2 = pd.read_csv('Downloads/Misery.csv')

# %%
data2.head().T
# Out:
#                  0       1       2       3       4
# Date        Jan 60  Feb 60  Mar 60  Apr 60  May 60
# Percentage    6.44    6.21    6.92    7.13    6.93
# Convert       in %    in %    in %    in %    in %

# %%
data2 = data2.drop(['Convert'],axis =1) # remove Convert
data2.head()
# Out:
#      Date  Percentage
# 0  Jan 60        6.44
# 1  Feb 60        6.21
# 2  Mar 60        6.92
# 3  Apr 60        7.13
# 4  May 60        6.93

# %%
list_Month = [i.split(' ')[0][:3] for i in list(data2['Date'])] # create column just for year and month
data2['Year'] =[x.strip()[4:6] for x in data2['Date']]


data2['Month'] = list_Month
data2.head()
# Out:
#      Date  Percentage Year Month
# 0  Jan 60        6.44   60   Jan
# 1  Feb 60        6.21   60   Feb
# 2  Mar 60        6.92   60   Mar
# 3  Apr 60        7.13   60   Apr
# 4  May 60        6.93   60   May

# %%
lists = (data,data2) # combine datasets
df = pd.concat(lists)
df.head().T
# Out:
#                0     1     2     3     4
# Year          90    91    92    93    94
# Poverty     13.5  14.2  14.8  15.1  14.5
# Rate        in %  in %  in %  in %  in %
# Date         NaN   NaN   NaN   NaN   NaN
# Percentage   NaN   NaN   NaN   NaN   NaN
# Month        NaN   NaN   NaN   NaN   NaN

# %%
df = df.drop(['Rate', "Date", 'Month'],axis =1) # remove unnecessary variables
df.tail()
# Out:
#     Year  Poverty  Percentage
# 748   22      NaN       12.12
# 749   22      NaN       12.60
# 750   22      NaN       11.99
# 751   22      NaN       11.95
# 752   22      NaN       11.72

# %%
df.tail()
# Out:
#     Year  Poverty  Percentage
# 748   22      NaN       12.12
# 749   22      NaN       12.60
# 750   22      NaN       11.99
# 751   22      NaN       11.95
# 752   22      NaN       11.72

# %%
df = pd.read_csv('Downloads/PovertyvsMisery.csv') # import combined dataset
df.head()
# Out:
#    Year  Poverty  Misery
# 0  1990     13.5   11.03
# 1  1991     14.2   11.08
# 2  1992     14.8   10.53
# 3  1993     15.1    9.88
# 4  1994     14.5    8.70

# %%
# Plot

sns.scatterplot(data=df, x='Year', y='Misery', 
                alpha=0.7, hue='Poverty')

leg = plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0,
           title = '% of Poverty Level', fontsize = '14', title_fontsize = '12')
plt.ylabel('Misery Index %')
plt.xlabel('Year')

plt.show()

# %%
fig = plt.figure(figsize= (20,14)) # graph all misery index
ax = sns.lineplot(data=data2, y="Percentage", x="Date", color = 'black', lw = 5 )


ax.xaxis.set_major_locator(ticker.MultipleLocator(60))
ax.tick_params(rotation=45)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        753 non-null    object
#  1   Percentage  753 non-null    float64
#  2   Year        753 non-null    object
#  3   Month       753 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 23.7+ KB

# %%
data2['Year'] = data2['Year'].astype('int') # convert Year to Int for cleaning

# %%
data_Vietnam = data2[(data2['Year'] >= 72) & (data2['Year'] <=75 )] # look at years just during Vietnam
data_Vietnam.tail()
# Out:
#        Date  Percentage  Year Month
# 187  Aug 75       17.02    75   Aug
# 188  Sep 75       16.31    75   Sep
# 189  Oct 75       16.05    75   Oct
# 190  Nov 75       15.68    75   Nov
# 191  Dec 75       15.33    75   Dec

# %%
fig = plt.figure(figsize= (14,10)) # plot this
ax = sns.lineplot(data=data_Vietnam, y="Percentage", x="Date", color = 'black', lw = 5 )

ax.xaxis.set_major_locator(ticker.MultipleLocator(12))
ax.tick_params(rotation=45)
plt.ylabel('Misery Index %')
plt.xlabel('Year')
plt.show()

# %%
f_c1 = pd.read_csv('Downloads/Suicide.csv') # input data and look at its structure
f_c1.head()
# Out:
#    Year  Count Status
# 0  2014      6  Prior
# 1  2014     31  After
# 2  2015      6  Prior
# 3  2015     40  After
# 4  2017      5  Prior

# %%
# plot side by side barplot
plt.figure(figsize=(20,10))
sns.barplot(x='Year', y='Count', hue='Status', palette=['tab:green', 'tab:blue'], data=f_c1)


plt.title('Percentage of veterans who considered taking their own lives before and after joining the U.S. military.')
# Out:
# Text(0.5, 1.0, 'Percentage of veterans who considered taking their own lives before and after joining the U.S. military.')

# %%
#pip install panel
#pip install pandas-bokeh
#pip install cufflinks
# If you haven't installed panel or pandas-bokeh before, use this

# %%
warnings.filterwarnings('ignore')  # ignore notifications
np.set_printoptions(suppress=True)  # Removing the scientific record in numpy
pd.set_option('display.float_format', '{:.10g}'.format)  # Removing the scientific record in pandas

# %%
pn.extension(comms='ipywidgets')
#making all charts public and setting a global theme
cf.set_config_file(sharing='public',theme='white',offline=True)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('MilitaryExpense_DashBoard/military expenditure.csv')

# %%
data.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965  ...        2009        2010        2011  \
# 0   NaN   NaN   NaN   NaN  ...         NaN         NaN         NaN
# 1   NaN   NaN   NaN   NaN  ... 251869514.8 298146852.5 325807003.7
# 2   NaN   NaN   NaN   NaN  ...  3311193245  3500794836  3639496374
# 3   NaN   NaN   NaN   NaN  ... 182736862.5   185893242 197006789.2
# 4   NaN   NaN   NaN   NaN  ...         NaN         NaN         NaN
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
data.tail()
# Out:
#              Name Code     Type                      Indicator Name     1960  \
# 259        Kosovo  XKX  Country  Military expenditure (current USD)      NaN
# 260   Yemen, Rep.  YEM  Country  Military expenditure (current USD)      NaN
# 261  South Africa  ZAF  Country  Military expenditure (current USD) 69999972
# 262        Zambia  ZMB  Country  Military expenditure (current USD)      NaN
# 263      Zimbabwe  ZWE  Country  Military expenditure (current USD)      NaN
#
#            1961        1962        1963        1964        1965  ...  \
# 259         NaN         NaN         NaN         NaN         NaN  ...
# 260         NaN         NaN         NaN         NaN         NaN  ...
# 261 113749954.5 186199925.5 188999924.4 271599891.4 289449884.2  ...
# 262         NaN         NaN         NaN         NaN         NaN  ...
# 263         NaN         NaN         NaN         NaN    15600000  ...
#
#            2009        2010        2011        2012        2013        2014  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            264 non-null    object
#  1   Code            264 non-null    object
#  2   Type            264 non-null    object
#  3   Indicator Name  264 non-null    object
#  4   1960            79 non-null     float64
#  5   1961            84 non-null     float64
#  6   1962            93 non-null     float64
#  7   1963            98 non-null     float64
#  8   1964            98 non-null     float64
#  9   1965            104 non-null    float64
#  10  1966            104 non-null    float64
#  11  1967            105 non-null    float64
#  12  1968            113 non-null    float64
#  13  1969            113 non-null    float64
#  14  1970            121 non-null    float64
#  15  1971            122 non-null    float64
#  16  1972            123 non-null    float64
# ...

# %%
data.describe()
# Out:
#                  1960            1961            1962            1963  \
# count              79              84              93              98
# mean       4482374175      4450649265      4520297302      4462434675
# std   1.447959133e+10 1.486998072e+10 1.560036988e+10 1.551552701e+10
# min                 0               0               0               0
# 25%       32050295.05     25717021.88      24842044.8     28661295.15
# 50%       140888888.9     120057316.3     170034222.7     182440164.1
# 75%       824048620.3       759087439     833229524.1     898756403.6
# max   6.777698838e+10 7.161495788e+10 7.889138569e+10  8.09728091e+10
#
#                  1964            1965            1966            1967  \
# count              98             104             104             105
# mean       4525730182      4429379525      5098435698      5757743569
# std   1.552208361e+10 1.544076433e+10 1.817987275e+10 2.092876192e+10
# ...

# %%
data.dropna(inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull().any()/data.shape[0]
# Out:
# Name             0
# Code             0
# Type             0
# Indicator Name   0
# 1960             0
#                  ..
# 2014             0
# 2015             0
# 2016             0
# 2017             0
# 2018             0
# Length: 63, dtype: float64

# %%
fig = plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot=True, cmap='GnBu')
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['Name', 'Code', 'Type', 'Indicator Name', '1960', '1961', '1962',
#        '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018'],
#       dtype='object')

# %%
import missingno as msno
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
data.hist(bins=5,figsize=(12,10))
# Out:
# array([[<AxesSubplot:title={'center':'1960'}>,
#         <AxesSubplot:title={'center':'1961'}>,
#         <AxesSubplot:title={'center':'1962'}>,
#         <AxesSubplot:title={'center':'1963'}>,
#         <AxesSubplot:title={'center':'1964'}>,
#         <AxesSubplot:title={'center':'1965'}>,
#         <AxesSubplot:title={'center':'1966'}>,
#         <AxesSubplot:title={'center':'1967'}>],
#        [<AxesSubplot:title={'center':'1968'}>,
#         <AxesSubplot:title={'center':'1969'}>,
#         <AxesSubplot:title={'center':'1970'}>,
#         <AxesSubplot:title={'center':'1971'}>,
#         <AxesSubplot:title={'center':'1972'}>,
#         <AxesSubplot:title={'center':'1973'}>,
#         <AxesSubplot:title={'center':'1974'}>,
#         <AxesSubplot:title={'center':'1975'}>],
#        [<AxesSubplot:title={'center':'1976'}>,
#         <AxesSubplot:title={'center':'1977'}>,
#         <AxesSubplot:title={'center':'1978'}>,
#         <AxesSubplot:title={'center':'1979'}>,
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Code', 'Type', 'Indicator Name', '1960', '1961', '1962',
#        '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018'],
#       dtype='object')

# %%
mpl.use('agg')

from matplotlib.figure import Figure
def mpl_plot(avg, highlight):
    fig = Figure()
    ax = fig.add_subplot()
    avg.plot(ax=ax)
    if len(highlight): highlight.plot(style='o', ax=ax)
    return fig

def find_outliers(variable='Military expenditure (current USD)', window=30, sigma=10, view_fn=mpl_plot):
    avg = data[variable].rolling(window=window).mean()
    residual = data[variable] - avg
    std = residual.rolling(window=window).std()
    outliers = (np.abs(residual) > std * sigma)
    return view_fn(avg, avg[outliers])

# %%
find_outliers(variable='Military expenditure(current USD)', window=20, sigma=10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Military expenditure(current USD)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import panel as pn
pn.extension()

window = pn.widgets.IntSlider(name='window', value=30, start=1, end=60)
sigma = pn.widgets.IntSlider(name='sigma', value=10, start=0, end=20)

interactive = pn.bind(find_outliers, window=window, sigma=sigma)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
data.columns=data.columns.str.strip()

# %%
first_app = pn.Column(window, sigma, interactive)

first_app
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Military expenditure (current USD)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
mpl.use('agg')

from matplotlib.figure import Figure
def mpl_plot(avg, highlight):
    fig = Figure()
    ax = fig.add_subplot()
    avg.plot(ax=ax)
    if len(highlight): highlight.plot(style='o', ax=ax)
    return fig

def find_outliers(variable='Military expenditure (% of general government expenditure)', window=30, sigma=10, view_fn=mpl_plot):
    avg = data[variable].rolling(window=window).mean()
    residual = data[variable] - avg
    std = residual.rolling(window=window).std()
    outliers = (np.abs(residual) > std * sigma)
    return view_fn(avg, avg[outliers])

# %%
find_outliers(variable='Military expenditure (% of general government expenditure)', window=20, sigma=10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Military expenditure (% of general government expenditure)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data.columns=data.columns.str.strip()

# %%
pn.extension()

window = pn.widgets.IntSlider(name='window', value=30, start=1, end=60)
sigma = pn.widgets.IntSlider(name='sigma', value=10, start=0, end=20)

interactive = pn.bind(find_outliers, window=window, sigma=sigma)

# %%
first_app = pn.Column(window, sigma, interactive)

first_app

# %%
mpl.use('agg')

from matplotlib.figure import Figure
def mpl_plot(avg, highlight):
    fig = Figure()
    ax = fig.add_subplot()
    avg.plot(ax=ax)
    if len(highlight): highlight.plot(style='o', ax=ax)
    return fig

def find_outliers(variable='Military expenditure (% of GDP)', window=30, sigma=10, view_fn=mpl_plot):
    avg = data[variable].rolling(window=window).mean()
    residual = data[variable] - avg
    std = residual.rolling(window=window).std()
    outliers = (np.abs(residual) > std * sigma)
    return view_fn(avg, avg[outliers])

# %%
find_outliers(variable='Military expenditure (% of GDP)', window=20, sigma=10)

# %%
pn.extension()

window = pn.widgets.IntSlider(name='window', value=30, start=1, end=60)
sigma = pn.widgets.IntSlider(name='sigma', value=10, start=0, end=20)

interactive = pn.bind(find_outliers, window=window, sigma=sigma)

# %%
first_app = pn.Column(window, sigma, interactive)

first_app

# %%
first_app.show()

# %%
first_app.servable();

# %%
data.iloc[:,3:].apply(pd.to_numeric,errors='coerce')

# %%
countries = data.country.unique().tolist()
print(f'All countries:\n{countries}')

# %%
rf = data.loc[df['incomeLevel'] != 'Aggregates', :]

# %%
plt.figure(figsize=(20,8))
years = [i for i in range(data['year'].min(), data['year'].max() + 1)]
plt.grid()
world_military_expenditure = data[data['country'] == 'World']['Military expenditure (current USD)']
sns.lineplot(years, world_military_expenditure)
plt.title('Military spending around the World for 1980-2020', fontsize=18)
plt.xlabel('Year', fontsize=18)
plt.ylabel('Spending', fontsize=18)
plt.xticks(rotation=30, fontsize=18)
plt.yticks(fontsize=18)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.title('Countries with the largest increase in military spending', fontsize=18)
plt.xlabel('Country', fontsize=18)
plt.ylabel('Maximum spending - minimum spending', fontsize=18)
sns.barplot(top_10.index, top_10.values)
plt.xticks(rotation=30, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
income_level_list = data['incomeLevel'].dropna().unique().tolist()
income_level_list.remove('Not classified')
income_level_list.remove('Aggregates')
income_level_list

# %%
ef = pd.DataFrame(data.groupby('incomeLevel').sum()['Military expenditure (current USD)'])
ef.drop(index=['Aggregates', 'Not classified'], inplace=True)
explode = (0.05, 0.05, 0.05, 0.05)
plt.figure(figsize=(10, 10))
plt.title('''The ratio of the total military spending of
countries with different levels of income of the population for the period 1970-2020''', fontsize=17)
plt.pie(ef['Military expenditure (current USD)'], labels=income_level_list, autopct='%1.1f%%', shadow=False,
        wedgeprops={'lw':1, 'ls':'--','edgecolor':'k'}, rotatelabels=True, explode=explode,
        colors = sns.color_palette('pastel')[0:4], textprops={'fontsize': 14})
plt.show()

# %%
data.plot_bokeh(kind='line')

# %%
data.iplot(x='year', y='Military expenditure (current USD)', kind='line')

# %%
data.iplot(kind='bar', x='incomeLevel', y='Military expenditure (current USD)');

# %%
df_2005 = pd.read_csv('2005.csv')       # creating variables for each file for suicide data

# %%
df_2006 = pd.read_csv('2006.csv')

# %%
df_2007 = pd.read_csv('2007.csv')

# %%
df_2008 = pd.read_csv('2008.csv')

# %%
df_2009 = pd.read_csv('2009.csv')

# %%
df_2010 = pd.read_csv('2010.csv')

# %%
df_2011 = pd.read_csv('2011.csv')

# %%
df_2005['vet_suicides'].mean()

# %%
df_2006['vet_suicides'].mean()      # finding the mean for each variable

# %%
df_2007['vet_suicides'].mean()

# %%
df_2008['vet_suicides'].mean()

# %%
df_2009['vet_suicides'].mean()

# %%
df_2010['vet_suicides'].mean()

# %%
df_2011['vet_suicides'].mean()

# %%
x = np.array([2005,2006,2007,2008,2009,2010,2011])
y = np.array([136.92,130.02,136.24,143.4,145.64,145.0,164.92])     # graph using the means gotten before  
  
plt.plot(x, y)
plt.xlabel("Year")  # add x-axis label 
plt.ylabel("Suicides")  # add y-axis label
plt.title("Average Vet Suicides Per Year")  # add title
plt.show()
