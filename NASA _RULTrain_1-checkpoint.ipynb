# %%
# %pip install missingno
# Out:
# ...
#   Obtaining dependency information for missingno from https://files.pythonhosted.org/packages/87/22/cd5cf999af21c2f97486622c551ac3d07361ced8125121e907f588ff5f24/missingno-0.5.2-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import os
import pandas as pd
import numpy as np
np.random.seed(1337)
from IPython.display import Image
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas import read_csv
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

import missingno as msno

# %%
#%pip install missingno

# %%
# settings will be used to avoid exponential values in output or tables and to display 50 rows maximum

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.max_rows=50

# %%
train = pd.read_excel('data/train_FD001.xlsx')
print(train.shape)
print(list(train.columns))
# Out:
# (20631, 26)
# ['unit', 'time', 'op1', 'op2', 'op3', 'sm1', 'sm2', 'sm3', 'sm4', 'sm5', 'sm6', 'sm7', 'sm8', 'sm9', 'sm10', 'sm11', 'sm12', 'sm13', 'sm14', 'sm15', 'sm16', 'sm17', 'sm18', 'sm19', 'sm20', 'sm21']

# %%
msno.matrix(train)
# Out:
# <Axes: >

# %%
train.head(5)
# Out:
#    unit  time    op1    op2  op3     sm1     sm2      sm3      sm4    sm5  \
# 0     1     1 -0.001 -0.000  100 518.670 641.820 1589.700 1400.600 14.620
# 1     1     2  0.002 -0.000  100 518.670 642.150 1591.820 1403.140 14.620
# 2     1     3 -0.004  0.000  100 518.670 642.350 1587.990 1404.200 14.620
# 3     1     4  0.001  0.000  100 518.670 642.350 1582.790 1401.870 14.620
# 4     1     5 -0.002 -0.000  100 518.670 642.370 1582.850 1406.220 14.620
#
#    ...    sm12     sm13     sm14  sm15  sm16  sm17  sm18  sm19   sm20   sm21
# 0  ... 521.660 2388.020 8138.620 8.419 0.030   392  2388   100 39.060 23.419
# 1  ... 522.280 2388.070 8131.490 8.432 0.030   392  2388   100 39.000 23.424
# 2  ... 522.420 2388.030 8133.230 8.418 0.030   390  2388   100 38.950 23.344
# 3  ... 522.860 2388.080 8133.830 8.368 0.030   392  2388   100 38.880 23.374
# 4  ... 522.190 2388.040 8133.800 8.429 0.030   393  2388   100 38.900 23.404
#
# [5 rows x 26 columns]

# %%
train.tail(5)
# Out:
#        unit  time    op1    op2  op3     sm1     sm2      sm3      sm4    sm5  \
# 20626   100   196 -0.000 -0.000  100 518.670 643.490 1597.980 1428.630 14.620
# 20627   100   197 -0.002 -0.001  100 518.670 643.540 1604.500 1433.580 14.620
# 20628   100   198  0.000  0.000  100 518.670 643.420 1602.460 1428.180 14.620
# 20629   100   199 -0.001  0.000  100 518.670 643.230 1605.260 1426.530 14.620
# 20630   100   200 -0.003 -0.001  100 518.670 643.850 1600.380 1432.140 14.620
#
#        ...    sm12     sm13     sm14  sm15  sm16  sm17  sm18  sm19   sm20  \
# 20626  ... 519.490 2388.260 8137.600 8.496 0.030   397  2388   100 38.490
# 20627  ... 519.680 2388.220 8136.500 8.514 0.030   395  2388   100 38.300
# 20628  ... 520.010 2388.240 8141.050 8.565 0.030   398  2388   100 38.440
# 20629  ... 519.670 2388.230 8139.290 8.539 0.030   395  2388   100 38.290
# 20630  ... 519.300 2388.260 8137.330 8.504 0.030   396  2388   100 38.370
#
#         sm21
# 20626 22.974
# 20627 23.159
# ...

# %%
train.describe()
# Out:
#            unit      time       op1       op2       op3       sm1       sm2  \
# count 20631.000 20631.000 20631.000 20631.000 20631.000 20631.000 20631.000
# mean     51.507   108.808    -0.000     0.000   100.000   518.670   642.681
# std      29.228    68.881     0.002     0.000     0.000     0.000     0.500
# min       1.000     1.000    -0.009    -0.001   100.000   518.670   641.210
# 25%      26.000    52.000    -0.002    -0.000   100.000   518.670   642.325
# 50%      52.000   104.000     0.000     0.000   100.000   518.670   642.640
# 75%      77.000   156.000     0.002     0.000   100.000   518.670   643.000
# max     100.000   362.000     0.009     0.001   100.000   518.670   644.530
#
#             sm3       sm4       sm5  ...      sm12      sm13      sm14  \
# count 20631.000 20631.000 20631.000  ... 20631.000 20631.000 20631.000
# mean   1590.523  1408.934    14.620  ...   521.413  2388.096  8143.753
# ...

# %%
plt.figure(figsize=(20,6))
train.unit.value_counts().plot.bar()
# Out:
# <Axes: xlabel='unit'>

# %%
### plotting sensor data for engine ID ###
engine_unit = train[train['unit'] == 1]

ax1 = engine_unit[train.columns[2:]].plot(subplots=True, sharex=True, figsize=(20,30))

# %%
### CALCULATE RUL TRAIN ###
train['RUL']=train.groupby(['unit'])['time'].transform(max)-train['time']
train.RUL[0:10]
# Out:
# 0    191
# 1    190
# 2    189
# 3    188
# 4    187
# 5    186
# 6    185
# 7    184
# 8    183
# 9    182
# Name: RUL, dtype: int64

# %%
### ADD NEW LABEL TRAIN ###
w1 = 45
w0 = 15
train['label1'] = np.where(train['RUL'] <= w1, 1, 0 )
train['label2'] = train['label1']
train.loc[train['RUL'] <= w0, 'label2'] = 2

# %%
### SCALE TRAIN DATA ###

def scale(df):
    return (df - df.mean())/df.std()
    return (df - df.min())/(df.max()-df.min())

for col in train.columns:
    if col[0] == 's':
        train[col] = scale(train[col])
    elif col == 'time':
        train['cycle_norm'] = scale(train[col])
        
train = train.dropna(axis=1)
train.head()
# Out:
#    unit  time    op1    op2  op3   sm1    sm2    sm3    sm4    sm5  ...  \
# 0     1     1 -0.001 -0.000  100 0.000 -1.722 -0.134 -0.926 -0.001  ...
# 1     1     2  0.002 -0.000  100 0.000 -1.062  0.212 -0.644 -0.001  ...
# 2     1     3 -0.004  0.000  100 0.000 -0.662 -0.413 -0.526 -0.001  ...
# 3     1     4  0.001  0.000  100 0.000 -0.662 -1.261 -0.785 -0.001  ...
# 4     1     5 -0.002 -0.000  100 0.000 -0.622 -1.251 -0.302 -0.001  ...
#
#     sm14   sm15   sm16   sm17  sm20  sm21  RUL  label1  label2  cycle_norm
# 0 -0.269 -0.604 -0.001 -0.782 1.348 1.194  191       0       0      -1.565
# 1 -0.643 -0.276 -0.001 -0.782 1.017 1.237  190       0       0      -1.551
# 2 -0.552 -0.649 -0.001 -2.073 0.740 0.503  189       0       0      -1.536
# 3 -0.520 -1.972 -0.001 -0.782 0.353 0.778  188       0       0      -1.522
# 4 -0.522 -0.340 -0.001 -0.136 0.463 1.060  187       0       0      -1.507
#
# [5 rows x 28 columns]

# %%
train.drop(['sm1', 'sm5', 'sm10', 'sm16', 
            'op3'], axis=1, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unit        20631 non-null  int64
#  1   time        20631 non-null  int64
#  2   op1         20631 non-null  float64
#  3   op2         20631 non-null  float64
#  4   sm2         20631 non-null  float64
#  5   sm3         20631 non-null  float64
#  6   sm4         20631 non-null  float64
#  7   sm6         20631 non-null  float64
#  8   sm7         20631 non-null  float64
#  9   sm8         20631 non-null  float64
#  10  sm9         20631 non-null  float64
#  11  sm11        20631 non-null  float64
#  12  sm12        20631 non-null  float64
#  13  sm13        20631 non-null  float64
#  14  sm14        20631 non-null  float64
#  15  sm15        20631 non-null  float64
#  16  sm17        20631 non-null  float64
#  17  sm20        20631 non-null  float64
# ...

# %%
nPlot1=2
nPlot2=8

fig,axes = plt.subplots (nrows = nPlot1, ncols=nPlot2)

plt.figure(figsize = (8, 8))
for i in 
    plt.plot(train[train.unit=={i}].time, train[train.unit=={1}].sm7)

plt.plot(train[train.unit==1].time, train[train.unit==1].sm7)
plt.plot(train[train.unit==2].time, train[train.unit==2].sm7)
plt.plot(train[train.unit==3].time, train[train.unit==3].sm7)
plt.plot(train[train.unit==4].time, train[train.unit==4].sm7)
plt.plot(train[train.unit==5].time, train[train.unit==5].sm7)
plt.plot(train[train.unit==6].time, train[train.unit==6].sm7)
plt.plot(train[train.unit==7].time, train[train.unit==7].sm7)
plt.plot(train[train.unit==8].time, train[train.unit==8].sm7)
plt.plot(train[train.unit==9].time, train[train.unit==9].sm7)
plt.plot(train[train.unit==10].time, train[train.unit==10].sm7)
plt.plot(train[train.unit==11].time, train[train.unit==11].sm7)
plt.xlabel('# Cycles')
plt.ylabel('Sensor measurements')
plt.show()

# %%
train.tail()
# Out:
#        unit  time    op1    op2   sm2   sm3   sm4   sm6    sm7   sm8  ...  \
# 20626   100   196 -0.000 -0.000 1.618 1.216 2.188 0.142 -2.189 1.315  ...
# 20627   100   197 -0.002 -0.001 1.718 2.280 2.738 0.142 -2.833 1.879  ...
# 20628   100   198  0.000  0.000 1.478 1.947 2.138 0.142 -2.743 2.019  ...
# 20629   100   199 -0.001  0.000 1.098 2.404 1.955 0.142 -3.037 2.160  ...
# 20630   100   200 -0.003 -0.001 2.338 1.608 2.578 0.142 -2.912 2.301  ...
#
#        sm13   sm14  sm15  sm17   sm20   sm21  RUL  label1  label2  cycle_norm
# 20626 2.278 -0.323 1.425 2.447 -1.805 -2.921    4       1       2       1.266
# 20627 1.722 -0.380 1.913 1.155 -2.856 -1.204    3       1       2       1.280
# 20628 2.000 -0.142 3.265 3.092 -2.082 -3.292    2       1       2       1.295
# 20629 1.861 -0.234 2.580 1.155 -2.912 -2.085    1       1       2       1.309
# 20630 2.278 -0.337 1.639 1.801 -2.469 -2.194    0       1       2       1.324
#
# [5 rows x 23 columns]

# %%
plt.figure(figsize = (8, 8))
for i in 100
    plt.plot(train[train.unit=={i}.time, train[train.unit=={i}].sm21)
#end
                   
plt.xlabel('# Cycles')
plt.ylabel('Sensor measurements')
plt.show()
# Out:
#   File "C:\Users\DuBious\AppData\Local\Temp\ipykernel_4024\1179291859.py", line 2
#     for i in 100
#                 ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize = (8, 8))
plt.plot(train[train.unit==1].time, train[train.unit==1].sm21)
plt.plot(train[train.unit==2].time, train[train.unit==2].sm21)
plt.plot(train[train.unit==3].time, train[train.unit==3].sm21)
plt.plot(train[train.unit==4].time, train[train.unit==4].sm21)
plt.plot(train[train.unit==5].time, train[train.unit==5].sm21)
plt.plot(train[train.unit==6].time, train[train.unit==6].sm21)
plt.plot(train[train.unit==7].time, train[train.unit==7].sm21)
plt.plot(train[train.unit==8].time, train[train.unit==8].sm21)
plt.plot(train[train.unit==9].time, train[train.unit==9].sm21)
plt.plot(train[train.unit==10].time, train[train.unit==10].sm21)
plt.plot(train[train.unit==11].time, train[train.unit==11].sm21)
plt.xlabel('# Cycles')
plt.ylabel('Sensor measurements')
plt.show()
